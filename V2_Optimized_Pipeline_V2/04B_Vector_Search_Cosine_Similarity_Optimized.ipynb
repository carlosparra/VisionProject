# %% [markdown]
# # 04B. Vector Search and Cosine Similarity Optimized — `proyecto_integrador_v2`
#
# Este notebook corresponde al **Paso 04B optimizado** del pipeline `proyecto_integrador_v2`.
#
# ## Objetivo
#
# Construir una búsqueda visual Top-K usando los embeddings generados en el Paso 03.
#
# En esta versión del proyecto, el objetivo principal no es encontrar perros de la misma raza, sino encontrar **perros visualmente similares**. Esto es la base para un sistema de perros perdidos/encontrados, donde una imagen nueva podrá compararse contra una base de perros reportados.
#
# ## Entrada
#
# Este notebook usa:
#
# ```text
# processed_data/embeddings/step03b_optimized_dog_embeddings_l2.npy
# processed_data/metadata/step03b_optimized_embeddings_metadata.csv
# ```
#
# ## Salidas
#
# El notebook generará:
#
# ```text
# processed_data/search_results/step04b_optimized_topk_neighbors.csv
# processed_data/search_results/step04b_optimized_similarity_summary.csv
# reports/tables/step04b_optimized_vector_search_indicators.csv
# reports/figures/step04b_optimized_similarity_examples.png
# ```

# %% [markdown]
# ## Enfoque
#
# Como los embeddings ya están normalizados con L2, la similitud coseno entre dos embeddings se puede calcular como producto punto:
#
# ```text
# cosine_similarity(a, b) = a · b
# ```
#
# El resultado va de menor a mayor similitud. Para este pipeline:
#
# - similitud alta → perros visualmente más parecidos,
# - similitud baja → perros visualmente menos parecidos.
#
# Este paso construye una búsqueda Top-K para encontrar los vecinos más similares de cada imagen.

# %%
# 0. Instalación de dependencias

# !pip install -q numpy pandas matplotlib pillow tqdm scikit-learn

# %% [markdown]
# ## Diferencia contra el Paso 04 original
#
# Esta versión **04B optimizada** reconstruye la búsqueda vectorial usando los embeddings generados por el **03B optimizado**, que a su vez vienen de los crops del **02B optimizado**.
#
# Entradas:
#
# ```text
# processed_data/embeddings/step03b_optimized_dog_embeddings_l2.npy
# processed_data/metadata/step03b_optimized_embeddings_metadata.csv
# ```
#
# El objetivo es comparar si la mejora de detección/crop también mejora la cobertura y calidad de búsqueda visual en toda la base.
#
# Los outputs usan prefijo:
#
# ```text
# step04b_optimized_...
# ```
#
# para no sobrescribir el Paso 04 original.

# %%
# 1. Imports y configuración general

from pathlib import Path
import json
import time
import math
from datetime import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from PIL import Image
from tqdm import tqdm

from sklearn.metrics.pairwise import cosine_similarity

pd.set_option("display.max_columns", 200)

SEED = 42
np.random.seed(SEED)

# %%
# 2. Montar Google Drive

from google.colab import drive

if Path("/content/drive/MyDrive").exists():
    print("Google Drive ya está montado.")
else:
    drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# 3. Rutas del proyecto

PROJECT_ROOT = Path("/content/drive/MyDrive/proyecto_integrador_v2")
CONFIG_PATH = PROJECT_ROOT / "project_config.json"

if CONFIG_PATH.exists():
    with open(CONFIG_PATH, "r", encoding="utf-8") as f:
        config = json.load(f)
else:
    config = {}

PROCESSED_DATA_PATH = PROJECT_ROOT / "processed_data"
EMBEDDINGS_PATH = PROCESSED_DATA_PATH / "embeddings"
METADATA_PATH = PROCESSED_DATA_PATH / "metadata"
SEARCH_RESULTS_PATH = PROCESSED_DATA_PATH / "search_results"

REPORTS_PATH = PROJECT_ROOT / "reports"
FIGURES_PATH = REPORTS_PATH / "figures"
TABLES_PATH = REPORTS_PATH / "tables"

for p in [SEARCH_RESULTS_PATH, REPORTS_PATH, FIGURES_PATH, TABLES_PATH]:
    p.mkdir(parents=True, exist_ok=True)

EMBEDDINGS_L2_PATH = EMBEDDINGS_PATH / "step03b_optimized_dog_embeddings_l2.npy"
EMBEDDINGS_METADATA_PATH = METADATA_PATH / "step03b_optimized_embeddings_metadata.csv"

TOP_K = 10
VISUAL_TOP_K = 5

SEARCH_VARIANT = "optimized_02b_03b_efficientnetb0"

print("PROJECT_ROOT:", PROJECT_ROOT)
print("EMBEDDINGS_L2_PATH:", EMBEDDINGS_L2_PATH)
print("EMBEDDINGS_METADATA_PATH:", EMBEDDINGS_METADATA_PATH)
print("TOP_K:", TOP_K)
print("SEARCH_VARIANT:", SEARCH_VARIANT)
# Out:
# PROJECT_ROOT: /content/drive/MyDrive/proyecto_integrador_v2
# EMBEDDINGS_L2_PATH: /content/drive/MyDrive/proyecto_integrador_v2/processed_data/embeddings/step03b_optimized_dog_embeddings_l2.npy
# EMBEDDINGS_METADATA_PATH: /content/drive/MyDrive/proyecto_integrador_v2/processed_data/metadata/step03b_optimized_embeddings_metadata.csv
# TOP_K: 10
# SEARCH_VARIANT: optimized_02b_03b_efficientnetb0

# %%
# 4. Cargar embeddings y metadata del Paso 03

if not EMBEDDINGS_L2_PATH.exists():
    raise FileNotFoundError(
        f"No se encontró {EMBEDDINGS_L2_PATH}. Ejecuta primero el Paso 03."
    )

if not EMBEDDINGS_METADATA_PATH.exists():
    raise FileNotFoundError(
        f"No se encontró {EMBEDDINGS_METADATA_PATH}. Ejecuta primero el Paso 03."
    )

embeddings_l2 = np.load(EMBEDDINGS_L2_PATH)
metadata_df = pd.read_csv(EMBEDDINGS_METADATA_PATH)

metadata_df = metadata_df.reset_index(drop=True)

if len(metadata_df) != embeddings_l2.shape[0]:
    print("Advertencia: metadata y embeddings tienen tamaños diferentes.")
    print("metadata:", len(metadata_df))
    print("embeddings:", embeddings_l2.shape[0])

    min_len = min(len(metadata_df), embeddings_l2.shape[0])
    metadata_df = metadata_df.head(min_len).copy()
    embeddings_l2 = embeddings_l2[:min_len]

print("Embeddings:", embeddings_l2.shape)
print("Metadata:", metadata_df.shape)

display(metadata_df.head())
# Out:
# Embeddings: (19568, 1280)
# Metadata: (19568, 50)
#                                           image_path  \
# 0  /content/drive/MyDrive/proyecto_integrador_v2/...
# 1  /content/drive/MyDrive/proyecto_integrador_v2/...
# 2  /content/drive/MyDrive/proyecto_integrador_v2/...
# 3  /content/drive/MyDrive/proyecto_integrador_v2/...
# 4  /content/drive/MyDrive/proyecto_integrador_v2/...
#
#                                     relative_path  source_type  dog_id  \
# 0  images/n02085620-Chihuahua/n02085620_10074.jpg  base_images     NaN
# 1  images/n02085620-Chihuahua/n02085620_10131.jpg  base_images     NaN
# 2  images/n02085620-Chihuahua/n02085620_10621.jpg  base_images     NaN
# 3   images/n02085620-Chihuahua/n02085620_1073.jpg  base_images     NaN
# 4  images/n02085620-Chihuahua/n02085620_10976.jpg  base_images     NaN
#
#    report_id             filename extension read_status  read_error  \
# 0        NaN  n02085620_10074.jpg      .jpg          ok         NaN
# 1        NaN  n02085620_10131.jpg      .jpg          ok         NaN
# 2        NaN  n02085620_10621.jpg      .jpg          ok         NaN
# 3        NaN   n02085620_1073.jpg      .jpg          ok         NaN
# 4        NaN  n02085620_10976.jpg      .jpg          ok         NaN
#
#                                   curated_image_path  \
# 0  /content/drive/MyDrive/proyecto_integrador_v2/...
# 1  /content/drive/MyDrive/proyecto_integrador_v2/...
# 2  /content/drive/MyDrive/proyecto_integrador_v2/...
# 3  /content/drive/MyDrive/proyecto_integrador_v2/...
# 4  /content/drive/MyDrive/proyecto_integrador_v2/...
#
#                               model_ready_image_path  width  height  \
# 0  /content/drive/MyDrive/proyecto_integrador_v2/...    333     500
# 1  /content/drive/MyDrive/proyecto_integrador_v2/...    395     495
# 2  /content/drive/MyDrive/proyecto_integrador_v2/...    500     298
# 3  /content/drive/MyDrive/proyecto_integrador_v2/...    345     500
# 4  /content/drive/MyDrive/proyecto_integrador_v2/...    322     484
#
#    aspect_ratio  brightness_mean  contrast_std  sharpness_laplacian_var  \
# 0      0.666000        80.933724     67.169699               782.019819
# 1      0.797980        57.823199     65.480311               361.080245
# 2      1.677852       140.799376     39.013514                99.042644
# 3      0.690000       113.087635     77.667901              1297.671480
# 4      0.665289       121.949656     38.751610               277.332779
#
#    saturation_mean  colorfulness  edge_density quality_label  quality_flags  \
# 0        70.510204     26.020002      0.086222          good           none
# 1       153.008863     50.975990      0.117330          good           none
# 2        45.400081     24.762783      0.027584    acceptable  low_sharpness
# 3        76.206643     24.119247      0.137217          good           none
# 4       118.489746     35.805992      0.048387          good           none
#
#                                 detection_input_path  \
# 0  /content/proyecto_integrador_v2/images_curated...
# 1  /content/proyecto_integrador_v2/images_curated...
# 2  /content/proyecto_integrador_v2/images_curated...
# 3  /content/proyecto_integrador_v2/images_curated...
# 4  /content/proyecto_integrador_v2/images_curated...
#
#                        original_detection_input_path  pipeline_step  \
# 0  /content/drive/MyDrive/proyecto_integrador_v2/...  02B_optimized
# 1  /content/drive/MyDrive/proyecto_integrador_v2/...  02B_optimized
# 2  /content/drive/MyDrive/proyecto_integrador_v2/...  02B_optimized
# 3  /content/drive/MyDrive/proyecto_integrador_v2/...  02B_optimized
# 4  /content/drive/MyDrive/proyecto_integrador_v2/...  02B_optimized
#
#   selected_yolo_model  conf_threshold  crop_margin  dog_detected  \
# 0          yolo26s.pt            0.15         0.35          True
# 1          yolo26s.pt            0.15         0.35          True
# 2          yolo26s.pt            0.15         0.35          True
# 3          yolo26s.pt            0.15         0.35          True
# 4          yolo26s.pt            0.15         0.35          True
#
#    num_dog_detections  best_confidence  best_area  best_x1  best_y1  best_x2  \
# 0                   1         0.911131   116640.0     31.0     18.0    274.0
# 1                   1         0.877236   165808.0     50.0      9.0    394.0
# 2                   1         0.956422    38178.0    145.0     46.0    334.0
# 3                   1         0.926782   146328.0      0.0     29.0    312.0
# 4                   1         0.953500    53851.0     91.0    105.0    248.0
#
#    best_y2 crop_status  crop_error  \
# 0    498.0          ok         NaN
# 1    491.0          ok         NaN
# 2    248.0          ok         NaN
# 3    498.0          ok         NaN
# 4    448.0          ok         NaN
#
#                                            crop_path  crop_width  crop_height  \
# 0  /content/proyecto_integrador_v2/dog_crops_opti...       333.0        500.0
# 1  /content/proyecto_integrador_v2/dog_crops_opti...       395.0        495.0
# 2  /content/proyecto_integrador_v2/dog_crops_opti...       321.0        298.0
# 3  /content/proyecto_integrador_v2/dog_crops_opti...       345.0        500.0
# 4  /content/proyecto_integrador_v2/dog_crops_opti...       265.0        484.0
#
#    needs_review_detection detection_review_reason  crop_x1  crop_y1  crop_x2  \
# 0                   False                    none      0.0      0.0    333.0
# 1                   False                    none      0.0      0.0    395.0
# 2                   False                    none     79.0      0.0    400.0
# 3                   False                    none      0.0      0.0    345.0
# 4                   False                    none     37.0      0.0    302.0
#
#    crop_y2                                 original_crop_path  \
# 0    500.0  /content/drive/MyDrive/proyecto_integrador_v2/...
# 1    495.0  /content/drive/MyDrive/proyecto_integrador_v2/...
# 2    298.0  /content/drive/MyDrive/proyecto_integrador_v2/...
# 3    500.0  /content/drive/MyDrive/proyecto_integrador_v2/...
# 4    484.0  /content/drive/MyDrive/proyecto_integrador_v2/...
#
#   embedding_status  embedding_error
# 0               ok              NaN
# 1               ok              NaN
# 2               ok              NaN
# 3               ok              NaN
# 4               ok              NaN

# %%
# 5. Validación de embeddings normalizados

norms = np.linalg.norm(embeddings_l2, axis=1)

print("Norma mínima:", norms.min())
print("Norma máxima:", norms.max())
print("Norma promedio:", norms.mean())

if np.allclose(norms.mean(), 1.0, atol=1e-3):
    print("OK: embeddings normalizados con L2.")
else:
    print("Advertencia: revisar normalización L2.")
# Out:
# Norma mínima: 0.9999997
# Norma máxima: 1.0000002
# Norma promedio: 1.0
# OK: embeddings normalizados con L2.

# %% [markdown]
# ## Selección de muestra para búsqueda
#
# Calcular vecinos para las 19,153 imágenes contra toda la base es posible, pero puede consumir memoria y tiempo.
#
# Por eso, este notebook usa dos modos:
#
# 1. **Modo muestra**: calcula Top-K para una muestra aleatoria.
# 2. **Modo completo**: calcula Top-K para toda la base por chunks.
#
# Por default dejamos activado el modo completo por chunks, que es más seguro en memoria.

# %%
# 6. Configuración de búsqueda Top-K

RUN_FULL_SEARCH = True
QUERY_SAMPLE_SIZE = 2000
CHUNK_SIZE = 512

if RUN_FULL_SEARCH:
    query_indices = np.arange(embeddings_l2.shape[0])
else:
    sample_size = min(QUERY_SAMPLE_SIZE, embeddings_l2.shape[0])
    query_indices = np.random.choice(embeddings_l2.shape[0], size=sample_size, replace=False)

print("Queries a procesar:", len(query_indices))
print("Base de búsqueda:", embeddings_l2.shape[0])
print("CHUNK_SIZE:", CHUNK_SIZE)
# Out:
# Queries a procesar: 19568
# Base de búsqueda: 19568
# CHUNK_SIZE: 512

# %%
# 7. Funciones de búsqueda Top-K por similitud coseno

def topk_cosine_search(query_vectors, database_vectors, query_indices, top_k=10):
    """Calcula Top-K vecinos para un batch de queries.

    Como los embeddings están normalizados L2, producto punto = similitud coseno.
    """
    sims = np.dot(query_vectors, database_vectors.T)

    rows = []

    for local_i, global_query_idx in enumerate(query_indices):
        sim_row = sims[local_i]

        # Excluir self-match si el query viene de la misma base
        sim_row = sim_row.copy()
        sim_row[global_query_idx] = -np.inf

        candidate_indices = np.argpartition(sim_row, -top_k)[-top_k:]
        top_indices = candidate_indices[np.argsort(sim_row[candidate_indices])[::-1]]

        query_meta = metadata_df.iloc[global_query_idx]

        for rank, neighbor_idx in enumerate(top_indices, start=1):
            neighbor_meta = metadata_df.iloc[int(neighbor_idx)]

            rows.append({
                "query_index": int(global_query_idx),
                "neighbor_rank": int(rank),
                "neighbor_index": int(neighbor_idx),
                "cosine_similarity": float(sim_row[neighbor_idx]),

                "query_crop_path": query_meta.get("crop_path", None),
                "query_original_crop_path": query_meta.get("original_crop_path", None),
                "query_source_type": query_meta.get("source_type", None),
                "query_quality_label": query_meta.get("quality_label", None),
                "query_dog_id": query_meta.get("dog_id", None),
                "query_report_id": query_meta.get("report_id", None),

                "neighbor_crop_path": neighbor_meta.get("crop_path", None),
                "neighbor_original_crop_path": neighbor_meta.get("original_crop_path", None),
                "neighbor_source_type": neighbor_meta.get("source_type", None),
                "neighbor_quality_label": neighbor_meta.get("quality_label", None),
                "neighbor_dog_id": neighbor_meta.get("dog_id", None),
                "neighbor_report_id": neighbor_meta.get("report_id", None),
            })

    return rows

# %%
# 8. Ejecutar búsqueda Top-K por chunks

topk_records = []
start = time.time()

total_chunks = math.ceil(len(query_indices) / CHUNK_SIZE)

for chunk_start in tqdm(range(0, len(query_indices), CHUNK_SIZE), total=total_chunks):
    chunk_query_indices = query_indices[chunk_start:chunk_start + CHUNK_SIZE]
    query_vectors = embeddings_l2[chunk_query_indices]

    chunk_rows = topk_cosine_search(
        query_vectors=query_vectors,
        database_vectors=embeddings_l2,
        query_indices=chunk_query_indices,
        top_k=TOP_K
    )

    topk_records.extend(chunk_rows)

topk_neighbors_df = pd.DataFrame(topk_records)

elapsed = (time.time() - start) / 60

print("Búsqueda terminada.")
print("Tiempo:", round(elapsed, 2), "minutos")
print("Filas Top-K:", len(topk_neighbors_df))

display(topk_neighbors_df.head(20))
# Out:
# 100%|██████████| 39/39 [00:49<00:00,  1.26s/it]
# Búsqueda terminada.
# Tiempo: 0.83 minutos
# Filas Top-K: 195680
#     query_index  neighbor_rank  neighbor_index  cosine_similarity  \
# 0             0              1              92           0.732324
# 1             0              2              21           0.719554
# 2             0              3              17           0.698549
# 3             0              4              30           0.662890
# 4             0              5           18338           0.659820
# 5             0              6              56           0.654922
# 6             0              7             104           0.654058
# 7             0              8              53           0.650966
# 8             0              9             148           0.650584
# 9             0             10           18395           0.631120
# 10            1              1              54           0.711524
# 11            1              2             147           0.687454
# 12            1              3             146           0.675613
# 13            1              4           14090           0.674639
# 14            1              5              56           0.672136
# 15            1              6              21           0.659326
# 16            1              7              69           0.653842
# 17            1              8              53           0.645518
# 18            1              9            1376           0.644594
# 19            1             10              99           0.644360
#
#                                       query_crop_path  \
# 0   /content/proyecto_integrador_v2/dog_crops_opti...
# 1   /content/proyecto_integrador_v2/dog_crops_opti...
# 2   /content/proyecto_integrador_v2/dog_crops_opti...
# 3   /content/proyecto_integrador_v2/dog_crops_opti...
# 4   /content/proyecto_integrador_v2/dog_crops_opti...
# 5   /content/proyecto_integrador_v2/dog_crops_opti...
# 6   /content/proyecto_integrador_v2/dog_crops_opti...
# 7   /content/proyecto_integrador_v2/dog_crops_opti...
# 8   /content/proyecto_integrador_v2/dog_crops_opti...
# 9   /content/proyecto_integrador_v2/dog_crops_opti...
# 10  /content/proyecto_integrador_v2/dog_crops_opti...
# 11  /content/proyecto_integrador_v2/dog_crops_opti...
# 12  /content/proyecto_integrador_v2/dog_crops_opti...
# 13  /content/proyecto_integrador_v2/dog_crops_opti...
# 14  /content/proyecto_integrador_v2/dog_crops_opti...
# 15  /content/proyecto_integrador_v2/dog_crops_opti...
# 16  /content/proyecto_integrador_v2/dog_crops_opti...
# 17  /content/proyecto_integrador_v2/dog_crops_opti...
# 18  /content/proyecto_integrador_v2/dog_crops_opti...
# 19  /content/proyecto_integrador_v2/dog_crops_opti...
#
#                              query_original_crop_path query_source_type  \
# 0   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 1   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 2   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 3   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 4   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 5   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 6   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 7   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 8   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 9   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 10  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 11  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 12  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 13  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 14  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 15  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 16  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 17  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 18  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 19  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
#
#    query_quality_label  query_dog_id  query_report_id  \
# 0                 good           NaN              NaN
# 1                 good           NaN              NaN
# 2                 good           NaN              NaN
# 3                 good           NaN              NaN
# 4                 good           NaN              NaN
# 5                 good           NaN              NaN
# 6                 good           NaN              NaN
# 7                 good           NaN              NaN
# 8                 good           NaN              NaN
# 9                 good           NaN              NaN
# 10                good           NaN              NaN
# 11                good           NaN              NaN
# 12                good           NaN              NaN
# 13                good           NaN              NaN
# 14                good           NaN              NaN
# 15                good           NaN              NaN
# 16                good           NaN              NaN
# 17                good           NaN              NaN
# 18                good           NaN              NaN
# 19                good           NaN              NaN
#
#                                    neighbor_crop_path  \
# 0   /content/proyecto_integrador_v2/dog_crops_opti...
# 1   /content/proyecto_integrador_v2/dog_crops_opti...
# 2   /content/proyecto_integrador_v2/dog_crops_opti...
# 3   /content/proyecto_integrador_v2/dog_crops_opti...
# 4   /content/proyecto_integrador_v2/dog_crops_opti...
# 5   /content/proyecto_integrador_v2/dog_crops_opti...
# 6   /content/proyecto_integrador_v2/dog_crops_opti...
# 7   /content/proyecto_integrador_v2/dog_crops_opti...
# 8   /content/proyecto_integrador_v2/dog_crops_opti...
# 9   /content/proyecto_integrador_v2/dog_crops_opti...
# 10  /content/proyecto_integrador_v2/dog_crops_opti...
# 11  /content/proyecto_integrador_v2/dog_crops_opti...
# 12  /content/proyecto_integrador_v2/dog_crops_opti...
# 13  /content/proyecto_integrador_v2/dog_crops_opti...
# 14  /content/proyecto_integrador_v2/dog_crops_opti...
# 15  /content/proyecto_integrador_v2/dog_crops_opti...
# 16  /content/proyecto_integrador_v2/dog_crops_opti...
# 17  /content/proyecto_integrador_v2/dog_crops_opti...
# 18  /content/proyecto_integrador_v2/dog_crops_opti...
# 19  /content/proyecto_integrador_v2/dog_crops_opti...
#
#                           neighbor_original_crop_path neighbor_source_type  \
# 0   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 1   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 2   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 3   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 4   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 5   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 6   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 7   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 8   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 9   /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 10  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 11  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 12  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 13  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 14  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 15  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 16  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 17  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 18  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
# 19  /content/drive/MyDrive/proyecto_integrador_v2/...          base_images
#
#    neighbor_quality_label  neighbor_dog_id  neighbor_report_id
# 0                    good              NaN                 NaN
# 1                    good              NaN                 NaN
# 2                    good              NaN                 NaN
# 3                    good              NaN                 NaN
# 4                    good              NaN                 NaN
# 5                    good              NaN                 NaN
# 6                    good              NaN                 NaN
# 7              acceptable              NaN                 NaN
# 8                    good              NaN                 NaN
# 9                    good              NaN                 NaN
# 10                   good              NaN                 NaN
# 11             acceptable              NaN                 NaN
# 12                   good              NaN                 NaN
# 13                   good              NaN                 NaN
# 14                   good              NaN                 NaN
# 15                   good              NaN                 NaN
# 16           needs_review              NaN                 NaN
# 17             acceptable              NaN                 NaN
# 18                   good              NaN                 NaN
# 19           needs_review              NaN                 NaN

# %%
# 9. Guardar resultados Top-K

TOPK_RESULTS_PATH = SEARCH_RESULTS_PATH / "step04b_optimized_topk_neighbors.csv"
TOPK_RESULTS_TIMESTAMPED_PATH = SEARCH_RESULTS_PATH / f"step04b_optimized_topk_neighbors_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"

topk_neighbors_df.to_csv(TOPK_RESULTS_PATH, index=False)
topk_neighbors_df.to_csv(TOPK_RESULTS_TIMESTAMPED_PATH, index=False)

# Copia en reports/tables
topk_neighbors_df.to_csv(TABLES_PATH / "step04b_optimized_topk_neighbors.csv", index=False)

print("Top-K guardado en:", TOPK_RESULTS_PATH)
print("Top-K con timestamp guardado en:", TOPK_RESULTS_TIMESTAMPED_PATH)
# Out:
# Top-K guardado en: /content/drive/MyDrive/proyecto_integrador_v2/processed_data/search_results/step04b_optimized_topk_neighbors.csv
# Top-K con timestamp guardado en: /content/drive/MyDrive/proyecto_integrador_v2/processed_data/search_results/step04b_optimized_topk_neighbors_20260530_191238.csv

# %% [markdown]
# ## Métricas de búsqueda visual
#
# En esta etapa todavía no estamos midiendo “mismo perro”, porque la base actual proviene principalmente del dataset base.
# Por eso medimos métricas generales de similitud visual:
#
# - similitud promedio del Top-1,
# - similitud promedio del Top-5,
# - similitud promedio del Top-10,
# - distribución de similitudes,
# - casos con similitud alta,
# - casos con similitud baja.
#
# Cuando se agregue `identity_test`, se podrán medir métricas reales de re-identificación, como Top-1 Same Dog Accuracy y Top-5 Same Dog Accuracy.

# %%
# 10. Métricas generales de similitud

top1_df = topk_neighbors_df[topk_neighbors_df["neighbor_rank"] == 1].copy()
top5_df = topk_neighbors_df[topk_neighbors_df["neighbor_rank"] <= 5].copy()
top10_df = topk_neighbors_df[topk_neighbors_df["neighbor_rank"] <= 10].copy()

avg_top1_similarity = float(top1_df["cosine_similarity"].mean()) if len(top1_df) > 0 else np.nan
avg_top5_similarity = float(top5_df["cosine_similarity"].mean()) if len(top5_df) > 0 else np.nan
avg_top10_similarity = float(top10_df["cosine_similarity"].mean()) if len(top10_df) > 0 else np.nan

median_top1_similarity = float(top1_df["cosine_similarity"].median()) if len(top1_df) > 0 else np.nan
min_top1_similarity = float(top1_df["cosine_similarity"].min()) if len(top1_df) > 0 else np.nan
max_top1_similarity = float(top1_df["cosine_similarity"].max()) if len(top1_df) > 0 else np.nan

high_similarity_cases = int((top1_df["cosine_similarity"] >= 0.90).sum()) if len(top1_df) > 0 else 0
possible_similarity_cases = int(((top1_df["cosine_similarity"] >= 0.80) & (top1_df["cosine_similarity"] < 0.90)).sum()) if len(top1_df) > 0 else 0
weak_similarity_cases = int(((top1_df["cosine_similarity"] >= 0.70) & (top1_df["cosine_similarity"] < 0.80)).sum()) if len(top1_df) > 0 else 0
low_similarity_cases = int((top1_df["cosine_similarity"] < 0.70).sum()) if len(top1_df) > 0 else 0

similarity_summary_df = pd.DataFrame([
    {"metric": "avg_top1_similarity", "value": avg_top1_similarity},
    {"metric": "avg_top5_similarity", "value": avg_top5_similarity},
    {"metric": "avg_top10_similarity", "value": avg_top10_similarity},
    {"metric": "median_top1_similarity", "value": median_top1_similarity},
    {"metric": "min_top1_similarity", "value": min_top1_similarity},
    {"metric": "max_top1_similarity", "value": max_top1_similarity},
    {"metric": "high_similarity_cases_top1_ge_0_90", "value": high_similarity_cases},
    {"metric": "possible_similarity_cases_top1_0_80_0_90", "value": possible_similarity_cases},
    {"metric": "weak_similarity_cases_top1_0_70_0_80", "value": weak_similarity_cases},
    {"metric": "low_similarity_cases_top1_lt_0_70", "value": low_similarity_cases},
])

SIMILARITY_SUMMARY_PATH = SEARCH_RESULTS_PATH / "step04b_optimized_similarity_summary.csv"
similarity_summary_df.to_csv(SIMILARITY_SUMMARY_PATH, index=False)
similarity_summary_df.to_csv(TABLES_PATH / "step04b_optimized_similarity_summary.csv", index=False)

display(similarity_summary_df)
print("Resumen de similitud guardado en:", SIMILARITY_SUMMARY_PATH)
# Out:
#                                      metric        value
# 0                       avg_top1_similarity     0.748953
# 1                       avg_top5_similarity     0.712403
# 2                      avg_top10_similarity     0.692329
# 3                    median_top1_similarity     0.749896
# 4                       min_top1_similarity     0.343993
# 5                       max_top1_similarity     1.000000
# 6        high_similarity_cases_top1_ge_0_90   819.000000
# 7  possible_similarity_cases_top1_0_80_0_90  4165.000000
# 8      weak_similarity_cases_top1_0_70_0_80  9374.000000
# 9         low_similarity_cases_top1_lt_0_70  5210.000000
# Resumen de similitud guardado en: /content/drive/MyDrive/proyecto_integrador_v2/processed_data/search_results/step04b_optimized_similarity_summary.csv

# %%
# 11. Indicadores finales del Paso 04

step04_indicators_df = pd.DataFrame([
    {"section": "input", "indicator": "num_embeddings", "value": embeddings_l2.shape[0]},
    {"section": "input", "indicator": "embedding_dimension", "value": embeddings_l2.shape[1]},
    {"section": "search", "indicator": "search_variant", "value": SEARCH_VARIANT},
    {"section": "search", "indicator": "top_k", "value": TOP_K},
    {"section": "search", "indicator": "queries_processed", "value": len(query_indices)},
    {"section": "search", "indicator": "database_size", "value": embeddings_l2.shape[0]},
    {"section": "search", "indicator": "run_full_search", "value": RUN_FULL_SEARCH},
    {"section": "similarity", "indicator": "avg_top1_similarity", "value": avg_top1_similarity},
    {"section": "similarity", "indicator": "avg_top5_similarity", "value": avg_top5_similarity},
    {"section": "similarity", "indicator": "avg_top10_similarity", "value": avg_top10_similarity},
    {"section": "similarity", "indicator": "median_top1_similarity", "value": median_top1_similarity},
    {"section": "similarity", "indicator": "high_similarity_cases_top1_ge_0_90", "value": high_similarity_cases},
    {"section": "similarity", "indicator": "possible_similarity_cases_top1_0_80_0_90", "value": possible_similarity_cases},
    {"section": "similarity", "indicator": "weak_similarity_cases_top1_0_70_0_80", "value": weak_similarity_cases},
    {"section": "similarity", "indicator": "low_similarity_cases_top1_lt_0_70", "value": low_similarity_cases},
    {"section": "paths", "indicator": "topk_results_path", "value": str(TOPK_RESULTS_PATH)},
    {"section": "paths", "indicator": "similarity_summary_path", "value": str(SIMILARITY_SUMMARY_PATH)},
])

STEP04_INDICATORS_PATH = TABLES_PATH / "step04b_optimized_vector_search_indicators.csv"
step04_indicators_df.to_csv(STEP04_INDICATORS_PATH, index=False)

display(step04_indicators_df)
print("Indicadores guardados en:", STEP04_INDICATORS_PATH)
# Out:
#        section                                 indicator  \
# 0        input                            num_embeddings
# 1        input                       embedding_dimension
# 2       search                            search_variant
# 3       search                                     top_k
# 4       search                         queries_processed
# 5       search                             database_size
# 6       search                           run_full_search
# 7   similarity                       avg_top1_similarity
# 8   similarity                       avg_top5_similarity
# 9   similarity                      avg_top10_similarity
# 10  similarity                    median_top1_similarity
# 11  similarity        high_similarity_cases_top1_ge_0_90
# 12  similarity  possible_similarity_cases_top1_0_80_0_90
# 13  similarity      weak_similarity_cases_top1_0_70_0_80
# 14  similarity         low_similarity_cases_top1_lt_0_70
# 15       paths                         topk_results_path
# 16       paths                   similarity_summary_path
#
#                                                 value
# 0                                               19568
# 1                                                1280
# 2                    optimized_02b_03b_efficientnetb0
# 3                                                  10
# 4                                               19568
# 5                                               19568
# 6                                                True
# 7                                            0.748953
# 8                                            0.712403
# 9                                            0.692329
# 10                                           0.749896
# 11                                                819
# 12                                               4165
# 13                                               9374
# 14                                               5210
# 15  /content/drive/MyDrive/proyecto_integrador_v2/...
# 16  /content/drive/MyDrive/proyecto_integrador_v2/...
# Indicadores guardados en: /content/drive/MyDrive/proyecto_integrador_v2/reports/tables/step04b_optimized_vector_search_indicators.csv

# %%
# 12. Histograma de similitud Top-1

if len(top1_df) > 0:
    plt.figure(figsize=(8, 4))
    plt.hist(top1_df["cosine_similarity"], bins=50)
    plt.title("Distribución de similitud coseno Top-1")
    plt.xlabel("Cosine similarity")
    plt.ylabel("Frecuencia")
    plt.tight_layout()

    HIST_PATH = FIGURES_PATH / "step04b_optimized_top1_similarity_distribution.png"
    plt.savefig(HIST_PATH, dpi=150)
    plt.show()

    print("Histograma guardado en:", HIST_PATH)
else:
    print("No hay datos Top-1 para graficar.")
# Out:
# Histograma guardado en: /content/drive/MyDrive/proyecto_integrador_v2/reports/figures/step04b_optimized_top1_similarity_distribution.png

# %% [markdown]
# ## Visualización de vecinos
#
# La siguiente sección muestra una imagen consulta y sus vecinos más similares.
# Para evitar problemas si las rutas locales de `/content` ya no existen, se usa preferentemente `original_crop_path`, que apunta a Google Drive.

# %%
# 13. Funciones de visualización de vecinos

def resolve_image_path(path_a, path_b=None):
    """Devuelve una ruta existente priorizando path_a y luego path_b."""
    for p in [path_a, path_b]:
        if p is None or pd.isna(p):
            continue
        p = Path(str(p))
        if p.exists():
            return str(p)
    return None


def show_query_neighbors(query_index, topk_df, metadata_df, top_k=5, save_path=None):
    query_meta = metadata_df.iloc[int(query_index)]

    query_img_path = resolve_image_path(
        query_meta.get("original_crop_path", None),
        query_meta.get("crop_path", None)
    )

    neighbors = (
        topk_df[
            (topk_df["query_index"] == int(query_index)) &
            (topk_df["neighbor_rank"] <= top_k)
        ]
        .sort_values("neighbor_rank")
    )

    image_paths = [query_img_path]
    titles = [f"Query\\nidx={query_index}"]

    for _, row in neighbors.iterrows():
        neighbor_path = resolve_image_path(
            row.get("neighbor_original_crop_path", None),
            row.get("neighbor_crop_path", None)
        )
        image_paths.append(neighbor_path)
        titles.append(
            f"Rank {int(row['neighbor_rank'])}\\n"
            f"cos={row['cosine_similarity']:.3f}"
        )

    cols = len(image_paths)
    plt.figure(figsize=(3.2 * cols, 3.8))

    for i, img_path in enumerate(image_paths):
        plt.subplot(1, cols, i + 1)

        if img_path is None:
            plt.text(0.5, 0.5, "Imagen no encontrada", ha="center", va="center")
            plt.axis("off")
            continue

        try:
            img = Image.open(img_path).convert("RGB")
            plt.imshow(img)
            plt.title(titles[i], fontsize=9)
            plt.axis("off")
        except Exception as e:
            plt.text(0.5, 0.5, f"Error\\n{e}", ha="center", va="center")
            plt.axis("off")

    plt.tight_layout()

    if save_path is not None:
        plt.savefig(save_path, dpi=150)

    plt.show()

# %%
# 14. Mostrar ejemplos de búsqueda visual

NUM_EXAMPLES = 5

if len(top1_df) > 0:
    # Mezclar ejemplos: algunos de alta similitud y algunos aleatorios.
    candidate_queries = top1_df.sort_values("cosine_similarity", ascending=False)["query_index"].head(50).tolist()
    random_queries = top1_df.sample(min(50, len(top1_df)), random_state=SEED)["query_index"].tolist()

    example_queries = list(dict.fromkeys(candidate_queries + random_queries))[:NUM_EXAMPLES]

    for qidx in example_queries:
        save_path = FIGURES_PATH / f"step04b_optimized_query_{qidx}_neighbors.png"
        show_query_neighbors(qidx, topk_neighbors_df, metadata_df, top_k=VISUAL_TOP_K, save_path=save_path)
        print("Ejemplo guardado en:", save_path)
else:
    print("No hay resultados Top-K para visualizar.")
# Out:
# Ejemplo guardado en: /content/drive/MyDrive/proyecto_integrador_v2/reports/figures/step04b_optimized_query_18275_neighbors.png
# Ejemplo guardado en: /content/drive/MyDrive/proyecto_integrador_v2/reports/figures/step04b_optimized_query_18291_neighbors.png
# Ejemplo guardado en: /content/drive/MyDrive/proyecto_integrador_v2/reports/figures/step04b_optimized_query_18983_neighbors.png
# Ejemplo guardado en: /content/drive/MyDrive/proyecto_integrador_v2/reports/figures/step04b_optimized_query_18834_neighbors.png
# Ejemplo guardado en: /content/drive/MyDrive/proyecto_integrador_v2/reports/figures/step04b_optimized_query_3801_neighbors.png

# %%
# 15. Casos de baja similitud para revisión

if len(top1_df) > 0:
    low_similarity_review_df = top1_df.sort_values("cosine_similarity", ascending=True).head(50).copy()

    LOW_SIMILARITY_REVIEW_PATH = SEARCH_RESULTS_PATH / "step04b_optimized_low_similarity_review_cases.csv"
    low_similarity_review_df.to_csv(LOW_SIMILARITY_REVIEW_PATH, index=False)

    display(low_similarity_review_df.head(10))
    print("Casos de baja similitud guardados en:", LOW_SIMILARITY_REVIEW_PATH)
else:
    print("No hay resultados Top-1.")
# Out:
#         query_index  neighbor_rank  neighbor_index  cosine_similarity  \
# 121510        12151              1           15950           0.343993
# 156650        15665              1           12749           0.402279
# 36080          3608              1            3256           0.415720
# 20430          2043              1             745           0.423850
# 127680        12768              1           13227           0.446007
# 109750        10975              1           12231           0.448920
# 45750          4575              1            4507           0.449046
# 161820        16182              1           18035           0.458160
# 193790        19379              1           19240           0.462813
# 189670        18967              1           18971           0.463310
#
#                                           query_crop_path  \
# 121510  /content/proyecto_integrador_v2/dog_crops_opti...
# 156650  /content/proyecto_integrador_v2/dog_crops_opti...
# 36080   /content/proyecto_integrador_v2/dog_crops_opti...
# 20430   /content/proyecto_integrador_v2/dog_crops_opti...
# 127680  /content/proyecto_integrador_v2/dog_crops_opti...
# 109750  /content/proyecto_integrador_v2/dog_crops_opti...
# 45750   /content/proyecto_integrador_v2/dog_crops_opti...
# 161820  /content/proyecto_integrador_v2/dog_crops_opti...
# 193790  /content/proyecto_integrador_v2/dog_crops_opti...
# 189670  /content/proyecto_integrador_v2/dog_crops_opti...
#
#                                  query_original_crop_path query_source_type  \
# 121510  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 156650  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 36080   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 20430   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 127680  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 109750  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 45750   /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 161820  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 193790  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
# 189670  /content/drive/MyDrive/proyecto_integrador_v2/...       base_images
#
#        query_quality_label  query_dog_id  query_report_id  \
# 121510                good           NaN              NaN
# 156650                good           NaN              NaN
# 36080                 good           NaN              NaN
# 20430                 good           NaN              NaN
# 127680                good           NaN              NaN
# 109750                good           NaN              NaN
# 45750                 good           NaN              NaN
# 161820          acceptable           NaN              NaN
# 193790                good           NaN              NaN
# 189670                good           NaN              NaN
#
#                                        neighbor_crop_path  \
# 121510  /content/proyecto_integrador_v2/dog_crops_opti...
# 156650  /content/proyecto_integrador_v2/dog_crops_opti...
# 36080   /content/proyecto_integrador_v2/dog_crops_opti...
# 20430   /content/proyecto_integrador_v2/dog_crops_opti...
# 127680  /content/proyecto_integrador_v2/dog_crops_opti...
# 109750  /content/proyecto_integrador_v2/dog_crops_opti...
# 45750   /content/proyecto_integrador_v2/dog_crops_opti...
# 161820  /content/proyecto_integrador_v2/dog_crops_opti...
# 193790  /content/proyecto_integrador_v2/dog_crops_opti...
# 189670  /content/proyecto_integrador_v2/dog_crops_opti...
#
#                               neighbor_original_crop_path  \
# 121510  /content/drive/MyDrive/proyecto_integrador_v2/...
# 156650  /content/drive/MyDrive/proyecto_integrador_v2/...
# 36080   /content/drive/MyDrive/proyecto_integrador_v2/...
# 20430   /content/drive/MyDrive/proyecto_integrador_v2/...
# 127680  /content/drive/MyDrive/proyecto_integrador_v2/...
# 109750  /content/drive/MyDrive/proyecto_integrador_v2/...
# 45750   /content/drive/MyDrive/proyecto_integrador_v2/...
# 161820  /content/drive/MyDrive/proyecto_integrador_v2/...
# 193790  /content/drive/MyDrive/proyecto_integrador_v2/...
# 189670  /content/drive/MyDrive/proyecto_integrador_v2/...
#
#        neighbor_source_type neighbor_quality_label  neighbor_dog_id  \
# 121510          base_images                   good              NaN
# 156650          base_images                   good              NaN
# 36080           base_images                   good              NaN
# 20430           base_images                   good              NaN
# 127680          base_images                   good              NaN
# 109750          base_images                   good              NaN
# 45750           base_images                   good              NaN
# 161820          base_images                   good              NaN
# 193790          base_images                   good              NaN
# 189670          base_images             acceptable              NaN
#
#         neighbor_report_id
# 121510                 NaN
# 156650                 NaN
# 36080                  NaN
# 20430                  NaN
# 127680                 NaN
# 109750                 NaN
# 45750                  NaN
# 161820                 NaN
# 193790                 NaN
# 189670                 NaN
# Casos de baja similitud guardados en: /content/drive/MyDrive/proyecto_integrador_v2/processed_data/search_results/step04b_optimized_low_similarity_review_cases.csv

# %% [markdown]
# # Análisis de métricas del Paso 04
#
# El Paso 04 evalúa si los embeddings generados en el Paso 03 permiten recuperar imágenes visualmente similares.
#
# Las métricas de similitud Top-1, Top-5 y Top-10 permiten entender qué tan cerca está cada imagen de sus vecinos más parecidos. Una similitud Top-1 alta indica que el sistema encontró una imagen visualmente muy cercana al query. Una similitud baja puede indicar un caso difícil, una imagen atípica, un crop de baja calidad o un perro con características menos representadas en la base.
#
# En esta etapa todavía no se debe interpretar la búsqueda como identificación definitiva del mismo perro. Para eso se necesita un conjunto `identity_test`, donde varias imágenes pertenezcan al mismo perro. Sin embargo, este paso valida que la base vectorial funciona y que el sistema puede recuperar vecinos visualmente similares.

# %% [markdown]
# # Conclusión del Paso 04
#
# Este notebook construye la primera versión de búsqueda visual por embeddings para `proyecto_integrador_v2`.
#
# A partir de los embeddings normalizados del Paso 03, se generó una búsqueda Top-K mediante similitud coseno. Los resultados permiten encontrar los perros visualmente más parecidos a una imagen consulta.
#
# Este paso convierte el proyecto en una base de búsqueda visual. La raza deja de ser el elemento central; ahora el componente principal es la comparación entre vectores visuales.
